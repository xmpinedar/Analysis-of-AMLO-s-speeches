# %%
#!pip install facebook-page-scraper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: facebook-page-scraper in c:\users\dsouz\appdata\roaming\python\python39\site-packages (4.0.3)
# Requirement already satisfied: webdriver-manager==3.2.2 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from facebook-page-scraper) (3.2.2)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\programdata\anaconda3\lib\site-packages (from facebook-page-scraper) (2.8.2)
# Requirement already satisfied: selenium-wire==4.3.1 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from facebook-page-scraper) (4.3.1)
# Requirement already satisfied: selenium==4.1.0 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from facebook-page-scraper) (4.1.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil==2.8.2->facebook-page-scraper) (1.16.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium==4.1.0->facebook-page-scraper) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium==4.1.0->facebook-page-scraper) (0.10.2)
# Requirement already satisfied: trio~=0.17 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium==4.1.0->facebook-page-scraper) (0.22.0)
# Requirement already satisfied: blinker>=1.4 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (1.6.2)
# Requirement already satisfied: kaitaistruct>=0.7 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (0.10)
# Requirement already satisfied: pyparsing>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (3.0.9)
# Requirement already satisfied: pysocks>=1.7.1 in c:\programdata\anaconda3\lib\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (1.7.1)
# Requirement already satisfied: h2>=4.0 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (4.1.0)
# Requirement already satisfied: pyasn1>=0.3.1 in c:\programdata\anaconda3\lib\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (0.4.8)
# Requirement already satisfied: certifi>=2019.9.11 in c:\programdata\anaconda3\lib\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (2022.9.14)
# Requirement already satisfied: pyOpenSSL>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (22.0.0)
# Requirement already satisfied: hyperframe>=6.0 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (6.0.1)
# Requirement already satisfied: pydivert>=2.0.3 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (2.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from selenium-wire==4.3.1->facebook-page-scraper) (1.2.0)
# Requirement already satisfied: configparser in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from webdriver-manager==3.2.2->facebook-page-scraper) (5.3.0)
# Requirement already satisfied: crayons in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from webdriver-manager==3.2.2->facebook-page-scraper) (0.4.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from webdriver-manager==3.2.2->facebook-page-scraper) (2.28.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from h2>=4.0->selenium-wire==4.3.1->facebook-page-scraper) (4.0.0)
# Requirement already satisfied: cryptography>=35.0 in c:\programdata\anaconda3\lib\site-packages (from pyOpenSSL>=19.1.0->selenium-wire==4.3.1->facebook-page-scraper) (37.0.1)
# Requirement already satisfied: outcome in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.10)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.15.1)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.1.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->selenium-wire==4.3.1->facebook-page-scraper) (0.14.0)
# Requirement already satisfied: colorama in c:\users\dsouz\appdata\roaming\python\python39\site-packages (from crayons->webdriver-manager==3.2.2->facebook-page-scraper) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager==3.2.2->facebook-page-scraper) (2.0.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium==4.1.0->facebook-page-scraper) (2.21)

# %%
#!pip show facebook_page_scraper
# Out:
# Name: facebook-page-scraper
# Version: 4.0.3
# Summary: Python package to scrap facebook's pages front end with no limitations
# Home-page: https://github.com/shaikhsajid1111/facebook_page_scraper
# Author: Sajid Shaikh
# Author-email: shaikhsajid3732@gmail.com
# License: MIT
# Location: c:\users\dsouz\appdata\roaming\python\python39\site-packages
# Requires: python-dateutil, selenium, selenium-wire, webdriver-manager
# Required-by:

# %%
allow_span = driver.find_element( By.XPATH, '//div[contains(@aria-label, "Allow")]/../following-sibling::div')
allow_span.click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38172\3755488297.py in <module>
# ----> 1 allow_span = driver.find_element( By.XPATH, '//div[contains(@aria-label, "Allow")]/../following-sibling::div')
#       2 allow_span.click()
#
# NameError: name 'driver' is not defined

# %%
from facebook_page_scraper import Facebook_scraper

# %%
#page_list = ['KimKardashian','arnold','joebiden','eminem','SmoshGames','Metallica','cnn']
page_list = ['lopezobrador.org.mx']

# %%
proxy_port = 10001
posts_count = 1000

# %%
browser = "Chrome"

# %%
timeout = 600
headless = False

# %%
page_list = ['lopezobrador.org.mx']

proxy_port = 10001

posts_count = 9000
browser = "Chrome"

timeout = 600 #600 seconds
headless = False

# Dir for output if we scrape directly to CSV
# Make sure to create this folder
directory = "D:\\facebook_scrape_results"

for page in page_list:
    #our proxy for this scrape
    proxy = f'username:password@us.smartproxy.com:{proxy_port}'
    #initializing a scraper
    scraper = Facebook_scraper(page, posts_count, browser, proxy=proxy, timeout=timeout, headless=headless)
    
    #Running the scraper in two ways:
    
    # 1
    # Scraping and printing out the result into the console window:
    
    # json_data = scraper.scrap_to_json()
    # print(json_data)
    
    # 2
    # Scraping and writing into output CSV file:
    
    filename = page
    scraper.scrap_to_csv(filename, directory)
    
    # Rotating our proxy to the next port so we could get a new IP and avoid blocks
    proxy_port += 1
# Out:
# 2023-04-26 23:21:16,137 - facebook_page_scraper.driver_initialization - INFO - Using: username:password@us.smartproxy.com:10001
# [WDM] - Current google-chrome version is 112.0.5615
# [WDM] - Get LATEST driver version for 112.0.5615
# [WDM] - Driver [C:\Users\dsouz\.wdm\drivers\chromedriver\win32\112.0.5615.49\chromedriver.exe] found in cache
# 2023-04-26 23:21:51,159 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '29 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '29 il'
# 2023-04-26 23:21:57,118 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:21:57,174 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '13 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '13 il'
# 2023-04-26 23:22:04,006 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '63 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '63 il'
# 2023-04-26 23:22:15,465 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '12 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '12 il'
# 2023-04-26 23:22:59,557 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:22:59,606 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '18 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '18 il'
# 2023-04-26 23:23:05,049 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '13 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '13 il'
# 2023-04-26 23:23:05,520 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:23:05,575 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '21 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '21 il'
# 2023-04-26 23:23:17,912 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:23:18,150 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:23:23,986 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:23:50,344 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '16 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '16 il'
# 2023-04-26 23:23:56,689 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:23:56,890 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '16 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '16 il'
# 2023-04-26 23:23:57,102 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '17 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '17 il'
# 2023-04-26 23:24:03,690 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '42 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '42 il'
# 2023-04-26 23:24:10,692 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:24:16,192 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:24:16,294 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '12 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '12 il'
# 2023-04-26 23:24:16,404 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:24:22,299 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '15 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '15 il'
# 2023-04-26 23:24:29,167 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:24:43,507 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '13 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '13 il'
# 2023-04-26 23:24:55,069 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:24:55,157 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:25:01,030 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '59 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '59 il'
# 2023-04-26 23:25:13,677 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:25:28,400 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '12 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '12 il'
# 2023-04-26 23:25:54,533 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '28 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '28 il'
# 2023-04-26 23:26:27,417 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:26:46,783 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '24 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '24 il'
# 2023-04-26 23:26:47,125 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:27:09,246 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '12 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '12 il'
# 2023-04-26 23:27:16,377 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:27:46,105 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '25 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '25 il'
# 2023-04-26 23:28:28,176 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '16 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '16 il'
# 2023-04-26 23:28:38,907 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '14 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '14 il'
# 2023-04-26 23:28:49,245 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '21 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '21 il'
# 2023-04-26 23:28:49,790 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:29:09,992 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '14 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '14 il'
# 2023-04-26 23:29:45,147 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:29:45,733 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:29:56,461 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:29:56,893 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:30:28,149 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '20 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '20 il'
# 2023-04-26 23:30:28,516 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '11 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '11 il'
# 2023-04-26 23:30:30,424 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '41 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '41 il'
# 2023-04-26 23:31:08,014 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '12 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 202, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(shares))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '12 il'
# 2023-04-26 23:31:20,397 - facebook_page_scraper.scraper - ERROR - Error at find_elements method : could not convert string to float: '10 il'
# Traceback (most recent call last):
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraper.py", line 270, in __find_elements
#     Scraping_utilities._Scraping_utilities__value_to_float(comments))
#   File "C:\Users\dsouz\AppData\Roaming\Python\Python39\site-packages\facebook_page_scraper\scraping_utilities.py", line 101, in __value_to_float
#     return float(x.replace('m', '')) * 1000000
# ValueError: could not convert string to float: '10 il'
# 2023-04-26 23:31:20,453 - facebook_page_scraper.scraper - INFO - Timeout...
